# %%
import torch
import torch_tensorrt
import numpy as np

from ESPNet import ESPNet

# %%
model = ESPNet()

prm = torch.load('/home/julio981007/drivable_area_research/checkpoints/orfd_AL_ESPNet(v2_p6q8r10)/model_20241106_235706', map_location='cpu')

model.load_state_dict(prm['model_state_dict'])

model.eval()
# Out:
# ESPNet(
#   (encoder): ESPNet_Encoder(
#     (level1): CBR(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=32)
#     )
#     (sample1): InputProjectionA(
#       (pool): ModuleList(
#         (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (sample2): InputProjectionA(
#       (pool): ModuleList(
#         (0-1): 2 x AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (sample3): InputProjectionA(
#       (pool): ModuleList(
#         (0-2): 3 x AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (b1): BR(
#       (bn): BatchNorm2d(35, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=35)
#     )
#     (level2_0): DownSamplerB(
#       (c1): C(
# ...

# %%
inputs_ids = torch.as_tensor(np.ones([1,3,512,512])).cuda()

torch.onnx.export(model, 
                  (inputs_ids), 
                  'tmp.onnx', 
                  input_names='inputs_ids', 
                  output_names='outputs', 
                  export_params=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 inputs_ids = torch.as_tensor(np.ones([1,3,512,512])).cuda()
# ----> 3 torch.onnx.export(model,
#       4                   (inputs_ids),
#       5                   'tmp.onnx',
#       6                   input_names='inputs_ids',
#       7                   output_names='outputs',
#       8                   export_params=True)
#
# File ~/anaconda3/envs/tensorrt/lib/python3.8/site-packages/torch/onnx/utils.py:506, in export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, custom_opsets, export_modules_as_functions)
#     188 @_beartype.beartype
#     189 def export(
#     190     model: Union[torch.nn.Module, torch.jit.ScriptModule, torch.jit.ScriptFunction],
#    (...)
# ...
